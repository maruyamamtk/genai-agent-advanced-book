# %%
import sys, pathlib

try:
    root = pathlib.Path(__vsc_ipynb_file__).resolve().parent.parent
except NameError:
    p = pathlib.Path().resolve()
    root = p.parent if p.name == "notebooks" else p

if str(root) not in sys.path:
    sys.path.insert(0, str(root))

# %%
from src.agent import HelpDeskAgent
from src.configs import Settings
from src.tools.search_xyz_manual import search_xyz_manual
from src.tools.search_xyz_qa import (
    search_xyz_qa,
)

# %%
settings = Settings()

# %%
agent = HelpDeskAgent(
    settings=settings,
    tools=[search_xyz_manual, search_xyz_qa],
)

# %%
question = """
お世話になっております。

現在、XYZシステムの利用を検討しており、以下の2点についてご教示いただければと存じます。

1. パスワードに利用可能な文字の制限について
当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

2. 最新リリースの取得方法について
最新のアップデート情報をどのように確認・取得できるかについてもお教えいただけますと幸いです。

お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。

"""

question = """
お世話になっております。

現在、XYZシステムを利用しており、以下の点についてご教示いただければと存じます。

1. 特定のプロジェクトに対してのみ通知を制限する方法について
特定のプロジェクトに対してのみ通知を制限する方法についてお教えいただけますと幸いです。

2. パスワードに利用可能な文字の制限について
当該システムにてパスワードを設定する際、使用可能な文字の範囲（例：英数字、記号、文字数制限など）について詳しい情報をいただけますでしょうか。安全かつシステムでの認証エラーを防ぐため、具体的な仕様を確認したいと考えております。

お忙しいところ恐縮ですが、ご対応のほどよろしくお願い申し上げます。
"""

# %% [markdown]
# ## ヘルプデスクエージェント全体を実行します

# %%
result = agent.run_agent(question)
# Out:
# 2026-04-26 12:38:16,341 INFO 🚀 Starting plan generation process...
# 2026-04-26 12:38:16,342 INFO Sending request to OpenAI...
# 2026-04-26 12:38:19,417 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:19,424 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:19,424 INFO Plan generation complete!
# 2026-04-26 12:38:19,435 INFO 🚀 Starting tool selection process...
# 2026-04-26 12:38:19,435 INFO 🚀 Starting tool selection process...
# 2026-04-26 12:38:19,435 INFO 🚀 Starting tool selection process...
# 2026-04-26 12:38:19,529 INFO Sending request to OpenAI...
# 2026-04-26 12:38:19,530 INFO Sending request to OpenAI...
# 2026-04-26 12:38:19,533 INFO Sending request to OpenAI...
# 2026-04-26 12:38:20,242 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:20,246 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:20,247 INFO Tool selection complete!
# 2026-04-26 12:38:20,249 INFO 🚀 Starting tool execution process...
# 2026-04-26 12:38:20,250 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 使用可能な文字"}
# 2026-04-26 12:38:20,288 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.037s]
# 2026-04-26 12:38:20,288 INFO Search results: 10 hits
# 2026-04-26 12:38:20,289 INFO Finished searching XYZ manual by keyword
# 2026-04-26 12:38:20,289 INFO Tool execution complete!
# 2026-04-26 12:38:20,290 INFO 🚀 Starting subtask answer creation process...
# 2026-04-26 12:38:20,291 INFO Sending request to OpenAI...
# 2026-04-26 12:38:20,502 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:20,504 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:20,505 INFO Tool selection complete!
# 2026-04-26 12:38:20,507 INFO 🚀 Starting tool execution process...
# 2026-04-26 12:38:20,508 INFO Searching XYZ manual by keyword: {"keywords":"パスワード 文字数制限"}
# 2026-04-26 12:38:20,537 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:20,539 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:20,539 INFO Tool selection complete!
# 2026-04-26 12:38:20,541 INFO 🚀 Starting tool execution process...
# 2026-04-26 12:38:20,542 INFO Searching XYZ manual by keyword: {"keywords":"特定のプロジェクト 通知 制限 設定方法"}
# 2026-04-26 12:38:20,563 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.020s]
# 2026-04-26 12:38:20,563 INFO Search results: 10 hits
# 2026-04-26 12:38:20,564 INFO Finished searching XYZ manual by keyword
# 2026-04-26 12:38:20,564 INFO Tool execution complete!
# 2026-04-26 12:38:20,565 INFO 🚀 Starting subtask answer creation process...
# 2026-04-26 12:38:20,566 INFO Sending request to OpenAI...
# 2026-04-26 12:38:20,573 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.064s]
# 2026-04-26 12:38:20,574 INFO Search results: 7 hits
# 2026-04-26 12:38:20,575 INFO Finished searching XYZ manual by keyword
# 2026-04-26 12:38:20,577 INFO Tool execution complete!
# 2026-04-26 12:38:20,579 INFO 🚀 Starting subtask answer creation process...
# 2026-04-26 12:38:20,580 INFO Sending request to OpenAI...
# 2026-04-26 12:38:21,708 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:21,714 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:21,714 INFO Subtask answer creation complete!
# 2026-04-26 12:38:21,716 INFO 🚀 Starting reflection process...
# 2026-04-26 12:38:21,716 INFO Sending request to OpenAI...
# 2026-04-26 12:38:22,039 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:22,041 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:22,041 INFO Subtask answer creation complete!
# 2026-04-26 12:38:22,042 INFO 🚀 Starting reflection process...
# 2026-04-26 12:38:22,043 INFO Sending request to OpenAI...
# 2026-04-26 12:38:22,382 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:22,385 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:22,385 INFO Subtask answer creation complete!
# 2026-04-26 12:38:22,388 INFO 🚀 Starting reflection process...
# 2026-04-26 12:38:22,388 INFO Sending request to OpenAI...
# 2026-04-26 12:38:22,545 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:22,548 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:22,549 INFO Reflection complete!
# 2026-04-26 12:38:22,704 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:22,705 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:22,706 INFO Reflection complete!
# 2026-04-26 12:38:22,707 INFO 🚀 Starting tool selection process...
# 2026-04-26 12:38:22,709 INFO Sending request to OpenAI...
# 2026-04-26 12:38:22,902 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:22,903 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:22,904 INFO Reflection complete!
# 2026-04-26 12:38:23,825 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:23,827 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:23,827 INFO Tool selection complete!
# 2026-04-26 12:38:23,828 INFO 🚀 Starting tool execution process...
# 2026-04-26 12:38:23,829 INFO Searching XYZ manual by keyword: {"keywords":"プロジェクト通知設定 通知制限方法"}
# 2026-04-26 12:38:23,849 INFO POST http://localhost:9200/documents/_search [status:200 duration:0.020s]
# 2026-04-26 12:38:23,850 INFO Search results: 10 hits
# 2026-04-26 12:38:23,850 INFO Finished searching XYZ manual by keyword
# 2026-04-26 12:38:23,850 INFO Tool execution complete!
# 2026-04-26 12:38:23,852 INFO 🚀 Starting subtask answer creation process...
# 2026-04-26 12:38:23,852 INFO Sending request to OpenAI...
# 2026-04-26 12:38:24,947 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:24,951 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:24,952 INFO Subtask answer creation complete!
# 2026-04-26 12:38:24,954 INFO 🚀 Starting reflection process...
# 2026-04-26 12:38:24,954 INFO Sending request to OpenAI...
# 2026-04-26 12:38:25,902 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:25,907 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:25,908 INFO Reflection complete!
# 2026-04-26 12:38:25,912 INFO 🚀 Starting tool selection process...
# 2026-04-26 12:38:25,916 INFO Sending request to OpenAI...
# 2026-04-26 12:38:26,587 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:26,591 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:26,591 INFO Tool selection complete!
# 2026-04-26 12:38:26,594 INFO 🚀 Starting tool execution process...
# 2026-04-26 12:38:26,595 INFO Searching XYZ QA by query: {"query":"特定のプロジェクト 通知 制限 設定方法"}
# 2026-04-26 12:38:26,641 INFO Generating embedding vector from input query
# 2026-04-26 12:38:28,579 INFO HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# 2026-04-26 12:38:28,610 INFO HTTP Request: POST http://localhost:6333/collections/documents/points/query "HTTP/1.1 200 OK"
# 2026-04-26 12:38:28,612 INFO Search results: 3 hits
# 2026-04-26 12:38:28,613 INFO Finished searching XYZ QA by query
# 2026-04-26 12:38:28,613 INFO Tool execution complete!
# 2026-04-26 12:38:28,615 INFO 🚀 Starting subtask answer creation process...
# 2026-04-26 12:38:28,616 INFO Sending request to OpenAI...
# 2026-04-26 12:38:30,584 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:30,587 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:30,587 INFO Subtask answer creation complete!
# 2026-04-26 12:38:30,590 INFO 🚀 Starting reflection process...
# 2026-04-26 12:38:30,590 INFO Sending request to OpenAI...
# 2026-04-26 12:38:31,127 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:31,130 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:31,130 INFO Reflection complete!
# 2026-04-26 12:38:31,134 INFO 🚀 Starting final answer creation process...
# 2026-04-26 12:38:31,135 INFO Sending request to OpenAI...
# 2026-04-26 12:38:34,521 INFO HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# 2026-04-26 12:38:34,523 INFO ✅ Successfully received response from OpenAI.
# 2026-04-26 12:38:34,524 INFO Final answer creation complete!

# %%
# 回答
print(result.answer)
# Out:
# お世話になっております。
#
# ご質問について以下の通り回答いたします。
#
# 1. **特定のプロジェクトに対してのみ通知を制限する方法について**
#
#    現在、XYZシステムでは特定のプロジェクトに対して通知を制限する機能は提供されておりません。プロジェクト単位で通知設定を細かくカスタマイズすることはできませんが、通知を手動でフィルタリングすることで重要な通知だけを確認する運用が可能です。また、通知の優先度を設定し、高優先度の通知のみ表示するようにカスタマイズすることも可能です。この機能については将来的な機能要望として検討されているとのことです。
#
# 2. **パスワードに利用可能な文字の制限について**
#
#    XYZシステムのパスワード設定における使用可能な文字の種類と文字数制限については以下の通りです：
#
#    - パスワードは最低8文字以上である必要があります。
#    - 大文字と小文字の両方を含む必要があります。
#    - 少なくとも1つの数字を含む必要があります。
#    - 少なくとも1つの特殊文字（例: !@#$%^&* など）を含む必要があります。
#
#    これらの条件を満たすことで、安全かつシステムでの認証エラーを防ぐことができます。
#
# ご不明な点がございましたら、引き続きご連絡ください。どうぞよろしくお願いいたします。
